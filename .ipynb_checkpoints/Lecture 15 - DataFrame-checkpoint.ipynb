# %%
import numpy as np

import pandas as  pd

from pandas import Series, DataFrame

# %%
import webbrowser
website = 'https://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame['First NFL Season']
# Out:
# 0     1960
# 1     1921
# 2     1920
# 3     1966
# 4     1960
# 5     1961
# 6     1996
# 7     1925
# 8     1960
# 9     1950
# 10    1933
# 11    1960
# 12    1953
# 13    1960
# 14    1976
# 15    1932
# 16    1995
# 17    1960
# 18    1937
# 19    1950
# 20    1933
# 21    1960
# 22    1960
# 23    1930
# 24    1968
# 25    1960
# 26    1995
# 27    1967
# 28    1966
# 29    2002
# 30    1920
# 31    1976
# Name: First NFL Season, dtype: int64

# %%
DataFrame(nfl_frame, columns=['Team', 'First NFL Season', 'Won', 'Lost'])
# Out:
#                        Team  First NFL Season  Won  Lost
# 0            Dallas Cowboys              1960  502   374
# 1         Green Bay Packers              1921  737   562
# 2             Chicago Bears              1920  749   579
# 3            Miami Dolphins              1966  445   351
# 4   New England Patriots[b]              1960  489   386
# 5         Minnesota Vikings              1961  470   390
# 6          Baltimore Ravens              1996  190   161
# 7           New York Giants              1925  687   585
# 8            Denver Broncos              1960  470   404
# 9       San Francisco 49ers              1950  528   460
# 10      Pittsburgh Steelers              1933  614   538
# 11          Oakland Raiders              1960  462   411
# 12    Indianapolis Colts[c]              1953  506   453
# 13       Kansas City Chiefs              1960  457   415
# 14         Seattle Seahawks              1976  334   325
# ...

# %%
DataFrame(nfl_frame, columns=['Team', 'First NFL Season', 'Stadium'])
# Out:
#                        Team  First NFL Season  Stadium
# 0            Dallas Cowboys              1960      NaN
# 1         Green Bay Packers              1921      NaN
# 2             Chicago Bears              1920      NaN
# 3            Miami Dolphins              1966      NaN
# 4   New England Patriots[b]              1960      NaN
# 5         Minnesota Vikings              1961      NaN
# 6          Baltimore Ravens              1996      NaN
# 7           New York Giants              1925      NaN
# 8            Denver Broncos              1960      NaN
# 9       San Francisco 49ers              1950      NaN
# 10      Pittsburgh Steelers              1933      NaN
# 11          Oakland Raiders              1960      NaN
# 12    Indianapolis Colts[c]              1953      NaN
# 13       Kansas City Chiefs              1960      NaN
# 14         Seattle Seahawks              1976      NaN
# 15      Washington Redskins              1932      NaN
# ...

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
nfl_frame.tail(5)
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 27    28    New Orleans Saints    786  349   432     5  0.447
# 28    29       Atlanta Falcons    800  351   443     6  0.443
# 29    30        Houston Texans    256  110   146     0  0.430
# 30    31     Arizona Cardinals  1,330  550   740    40  0.429
# 31    32  Tampa Bay Buccaneers    660  255   404     1  0.387
#
#     First NFL Season   Division
# 27              1967  NFC South
# 28              1966  NFC South
# 29              2002  AFC South
# 30              1920   NFC West
# 31              1976  NFC South

# %%
nfl_frame.loc[3]
# Out:
# Rank                             4
# Team                Miami Dolphins
# GP                             800
# Won                            445
# Lost                           351
# Tied                             4
# Pct.                         0.559
# First NFL Season              1966
# Division                  AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
nfl_frame['Stadium'] = np.arange(32)

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index=[4, 0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
data = {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3880000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
#For full list of ways to create DataFrames from various sources go to teh documentation for pandas:
website = 'http://pandas-docs.github.io/pandas-docs-travis/generated/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
